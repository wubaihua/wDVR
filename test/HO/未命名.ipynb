# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

wf=pd.read_csv('HO_eigen_wavefun.out',header=None,sep='\s+').values

plt.plot(wf[:,0],wf[:,1])
plt.plot(wf[:,0],np.exp(-wf[:,0]**2/2)/(np.pi)**0.25)
plt.show()
